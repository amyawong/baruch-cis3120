# %% [markdown]
# 16. Write a python program to calculate the volume of a sphere. Your program will prompt the user to enter the radius of the sphere and will store this information. It will then perform the
# calculation using the formula provided below. You may assume Pi to be 3.14.
# &nbsp;&nbsp;&nbsp;&nbsp;
# If the volume is 434, the program will print 'this looks like a basketball.' If the volume is 9.6, 'the program will print this looks like a tennis ball. '
# &nbsp;&nbsp;&nbsp;&nbsp;
# Ensure that your output is formatted to 2 decimal places.
# ![](data:image/jpeg;base64,...)
